# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 5s 74us/sample - loss: 0.6540 - accuracy: 0.5818 - val_loss: 0.5801 - val_accuracy: 0.6630
# Epoch 2/200
# 71786/71786 [==============================] - 3s 46us/sample - loss: 0.5764 - accuracy: 0.6530 - val_loss: 0.5198 - val_accuracy: 0.7078
# Epoch 3/200
# 71786/71786 [==============================] - 4s 53us/sample - loss: 0.5374 - accuracy: 0.6787 - val_loss: 0.4923 - val_accuracy: 0.7241
# Epoch 4/200
# 71786/71786 [==============================] - 4s 52us/sample - loss: 0.5165 - accuracy: 0.6876 - val_loss: 0.4810 - val_accuracy: 0.7291
# Epoch 5/200
# 71786/71786 [==============================] - 2s 30us/sample - loss: 0.5023 - accuracy: 0.6994 - val_loss: 0.4726 - val_accuracy: 0.7357
# Epoch 6/200
# 71786/71786 [==============================] - 4s 55us/sample - loss: 0.4939 - accuracy: 0.7021 - val_loss: 0.4691 - val_accuracy: 0.7369
# Epoch 7/200
# ...
