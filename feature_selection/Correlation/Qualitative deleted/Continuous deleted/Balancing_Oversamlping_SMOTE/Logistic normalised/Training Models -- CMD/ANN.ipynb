# %%
import warnings
from pylab import rcParams
from tensorflow_core.python.keras.wrappers.scikit_learn import KerasClassifier
rcParams['figure.figsize'] = 10, 5
from sklearn.model_selection import GridSearchCV
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
import csv
from sklearn.metrics import accuracy_score
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[4:-1]
    cwd='/'.join(cwd)
    return cwd

def get_csv_path():
    import os
    cwd = os.getcwd()
    s="\\"
    if "\\" not in cwd:
        s='/'
    file= cwd.split(s)[:4]
    file.append('models_scores.csv')
    file= s.join(file)
    return file

def line_is_exist(file, row):
    logfile = open(file, 'r')
    loglist = logfile.readlines()
    logfile.close()
    for line in loglist:
        if ','.join(row) in line:
            return True
    return False

def write_new_score(file, line):
    if( not line_is_exist(file, line) ):
        with open(file, 'a') as f:
            writer = csv.writer(f)
            writer.writerow(line)
    else:
        print('line exsist already')

# %%
data= pd.read_csv('../logis_norm.csv')
### split data en X et Y
data1= data.copy()
X= data1.drop('Loan Status', axis=1)
Y= data1['Loan Status']

X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size = 0.30, random_state = 123)

### Neural Network
## ANN Model
def create_model(optimizer):
    model = Sequential()
	#Layer 1
    model.add(Dense(20, activation='relu', input_dim=20))
    model.add(Dropout(0.3))
    #Layer 2
    model.add(Dense(10, activation='relu'))
    model.add(Dropout(0.3))
    
    # output layer
    model.add(Dense(units=1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=50)
ANN = KerasClassifier(build_fn=create_model)

params={'optimizer' : ['adam', 'rmsprop'],
        'batch_size': [128, 256, 512, 800]}


##accuracy
grid_search_acc= GridSearchCV(estimator=ANN, param_grid= params, scoring='accuracy',cv=2, n_jobs=-1)
grid_search_acc= grid_search_acc.fit(X_train, Y_train, epochs=300, validation_data=(X_test, Y_test), callbacks=[early_stop])
y_predict= grid_search_acc.best_estimator_.predict(X_test)
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/300
# 71786/71786 [==============================] - 2s 30us/sample - loss: 0.6872 - accuracy: 0.5590 - val_loss: 0.6648 - val_accuracy: 0.6016
# Epoch 2/300
# 71786/71786 [==============================] - 2s 22us/sample - loss: 0.6678 - accuracy: 0.6004 - val_loss: 0.6503 - val_accuracy: 0.6335
# Epoch 3/300
# 71786/71786 [==============================] - 2s 22us/sample - loss: 0.6571 - accuracy: 0.6212 - val_loss: 0.6387 - val_accuracy: 0.6714
# Epoch 4/300
# 71786/71786 [==============================] - 2s 23us/sample - loss: 0.6498 - accuracy: 0.6315 - val_loss: 0.6224 - val_accuracy: 0.6828
# Epoch 5/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.6410 - accuracy: 0.6411 - val_loss: 0.6078 - val_accuracy: 0.6896
# Epoch 6/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.6301 - accuracy: 0.6534 - val_loss: 0.5894 - val_accuracy: 0.7017
# Epoch 7/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.6211 - accuracy: 0.6636 - val_loss: 0.5750 - val_accuracy: 0.7129
# Epoch 8/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.6121 - accuracy: 0.6726 - val_loss: 0.5674 - val_accuracy: 0.7286
# Epoch 9/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.6063 - accuracy: 0.6757 - val_loss: 0.5571 - val_accuracy: 0.7459
# Epoch 10/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.6018 - accuracy: 0.6836 - val_loss: 0.5499 - val_accuracy: 0.7499
# Epoch 11/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5979 - accuracy: 0.6847 - val_loss: 0.5465 - val_accuracy: 0.7402
# Epoch 12/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5948 - accuracy: 0.6878 - val_loss: 0.5381 - val_accuracy: 0.7414
# Epoch 13/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5892 - accuracy: 0.6930 - val_loss: 0.5335 - val_accuracy: 0.7480
# Epoch 14/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5876 - accuracy: 0.6949 - val_loss: 0.5369 - val_accuracy: 0.7440
# Epoch 15/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5872 - accuracy: 0.6942 - val_loss: 0.5314 - val_accuracy: 0.7522
# Epoch 16/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5839 - accuracy: 0.6973 - val_loss: 0.5309 - val_accuracy: 0.7511
# Epoch 17/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5817 - accuracy: 0.6992 - val_loss: 0.5229 - val_accuracy: 0.7520
# Epoch 18/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5823 - accuracy: 0.7011 - val_loss: 0.5219 - val_accuracy: 0.7560
# Epoch 19/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5816 - accuracy: 0.7007 - val_loss: 0.5235 - val_accuracy: 0.7608
# Epoch 20/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5792 - accuracy: 0.7037 - val_loss: 0.5200 - val_accuracy: 0.7512
# Epoch 21/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5785 - accuracy: 0.7033 - val_loss: 0.5144 - val_accuracy: 0.7747
# Epoch 22/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5792 - accuracy: 0.7027 - val_loss: 0.5183 - val_accuracy: 0.7455
# Epoch 23/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5769 - accuracy: 0.7050 - val_loss: 0.5198 - val_accuracy: 0.7563
# Epoch 24/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5763 - accuracy: 0.7039 - val_loss: 0.5126 - val_accuracy: 0.7561
# Epoch 25/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5752 - accuracy: 0.7065 - val_loss: 0.5156 - val_accuracy: 0.7511
# Epoch 26/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5726 - accuracy: 0.7059 - val_loss: 0.5093 - val_accuracy: 0.7627
# Epoch 27/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5748 - accuracy: 0.7060 - val_loss: 0.5111 - val_accuracy: 0.7536
# Epoch 28/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5726 - accuracy: 0.7054 - val_loss: 0.5139 - val_accuracy: 0.7565
# Epoch 29/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5726 - accuracy: 0.7084 - val_loss: 0.5121 - val_accuracy: 0.7647
# Epoch 30/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5706 - accuracy: 0.7094 - val_loss: 0.5081 - val_accuracy: 0.7778
# Epoch 31/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5701 - accuracy: 0.7087 - val_loss: 0.5162 - val_accuracy: 0.7538
# Epoch 32/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5702 - accuracy: 0.7094 - val_loss: 0.5065 - val_accuracy: 0.7756
# Epoch 33/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5701 - accuracy: 0.7078 - val_loss: 0.5078 - val_accuracy: 0.7812
# Epoch 34/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5710 - accuracy: 0.7070 - val_loss: 0.5083 - val_accuracy: 0.7736
# Epoch 35/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5712 - accuracy: 0.7074 - val_loss: 0.5105 - val_accuracy: 0.7780
# Epoch 36/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5686 - accuracy: 0.7105 - val_loss: 0.5061 - val_accuracy: 0.7633
# Epoch 37/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5689 - accuracy: 0.7119 - val_loss: 0.5100 - val_accuracy: 0.7714
# Epoch 38/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5702 - accuracy: 0.7076 - val_loss: 0.5059 - val_accuracy: 0.7573
# Epoch 39/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5701 - accuracy: 0.7093 - val_loss: 0.5059 - val_accuracy: 0.7647
# Epoch 40/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5677 - accuracy: 0.7094 - val_loss: 0.5050 - val_accuracy: 0.7768
# Epoch 41/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5679 - accuracy: 0.7113 - val_loss: 0.5057 - val_accuracy: 0.7806
# Epoch 42/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5676 - accuracy: 0.7117 - val_loss: 0.5048 - val_accuracy: 0.7482
# Epoch 43/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5668 - accuracy: 0.7137 - val_loss: 0.5004 - val_accuracy: 0.7826
# Epoch 44/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5650 - accuracy: 0.7151 - val_loss: 0.4989 - val_accuracy: 0.7757
# Epoch 45/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5685 - accuracy: 0.7102 - val_loss: 0.4998 - val_accuracy: 0.7695
# Epoch 46/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5682 - accuracy: 0.7125 - val_loss: 0.4974 - val_accuracy: 0.7814
# Epoch 47/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5669 - accuracy: 0.7126 - val_loss: 0.5062 - val_accuracy: 0.7615
# Epoch 48/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5666 - accuracy: 0.7123 - val_loss: 0.5043 - val_accuracy: 0.7792
# Epoch 49/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5650 - accuracy: 0.7127 - val_loss: 0.5041 - val_accuracy: 0.7692
# Epoch 50/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5674 - accuracy: 0.7112 - val_loss: 0.5082 - val_accuracy: 0.7807
# Epoch 51/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5691 - accuracy: 0.7116 - val_loss: 0.5050 - val_accuracy: 0.7720
# Epoch 52/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5653 - accuracy: 0.7140 - val_loss: 0.5064 - val_accuracy: 0.7795
# Epoch 53/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5665 - accuracy: 0.7129 - val_loss: 0.5039 - val_accuracy: 0.7783
# Epoch 54/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5685 - accuracy: 0.7119 - val_loss: 0.5072 - val_accuracy: 0.7805
# Epoch 55/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5636 - accuracy: 0.7144 - val_loss: 0.5135 - val_accuracy: 0.7677
# Epoch 56/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5680 - accuracy: 0.7110 - val_loss: 0.5065 - val_accuracy: 0.7803
# Epoch 57/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5653 - accuracy: 0.7151 - val_loss: 0.5007 - val_accuracy: 0.7552
# Epoch 58/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5676 - accuracy: 0.7123 - val_loss: 0.5014 - val_accuracy: 0.7827
# Epoch 59/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5663 - accuracy: 0.7129 - val_loss: 0.5044 - val_accuracy: 0.7772
# Epoch 60/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5655 - accuracy: 0.7150 - val_loss: 0.5057 - val_accuracy: 0.7733
# Epoch 61/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5636 - accuracy: 0.7155 - val_loss: 0.5046 - val_accuracy: 0.7801
# Epoch 62/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5670 - accuracy: 0.7104 - val_loss: 0.5055 - val_accuracy: 0.7813
# Epoch 63/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5635 - accuracy: 0.7156 - val_loss: 0.5022 - val_accuracy: 0.7826
# Epoch 64/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5664 - accuracy: 0.7130 - val_loss: 0.5029 - val_accuracy: 0.7835
# Epoch 65/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5662 - accuracy: 0.7130 - val_loss: 0.4980 - val_accuracy: 0.7816
# Epoch 66/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5653 - accuracy: 0.7158 - val_loss: 0.5008 - val_accuracy: 0.7862
# Epoch 67/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5633 - accuracy: 0.7149 - val_loss: 0.4982 - val_accuracy: 0.7614
# Epoch 68/300
# 71786/71786 [==============================] - 2s 27us/sample - loss: 0.5633 - accuracy: 0.7135 - val_loss: 0.5015 - val_accuracy: 0.7841
# Epoch 69/300
# 71786/71786 [==============================] - 2s 27us/sample - loss: 0.5638 - accuracy: 0.7163 - val_loss: 0.5000 - val_accuracy: 0.7860
# Epoch 70/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5679 - accuracy: 0.7133 - val_loss: 0.5056 - val_accuracy: 0.7832
# Epoch 71/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5646 - accuracy: 0.7154 - val_loss: 0.5029 - val_accuracy: 0.7795
# Epoch 72/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5650 - accuracy: 0.7142 - val_loss: 0.5085 - val_accuracy: 0.7723
# Epoch 73/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5654 - accuracy: 0.7138 - val_loss: 0.4952 - val_accuracy: 0.7853
# Epoch 74/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5636 - accuracy: 0.7148 - val_loss: 0.5006 - val_accuracy: 0.7782
# Epoch 75/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5654 - accuracy: 0.7150 - val_loss: 0.4987 - val_accuracy: 0.7745
# Epoch 76/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5648 - accuracy: 0.7134 - val_loss: 0.5017 - val_accuracy: 0.7834
# Epoch 77/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5632 - accuracy: 0.7167 - val_loss: 0.5031 - val_accuracy: 0.7779
# Epoch 78/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5667 - accuracy: 0.7128 - val_loss: 0.4983 - val_accuracy: 0.7715
# Epoch 79/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5652 - accuracy: 0.7139 - val_loss: 0.5030 - val_accuracy: 0.7825
# Epoch 80/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5666 - accuracy: 0.7142 - val_loss: 0.4979 - val_accuracy: 0.7809
# Epoch 81/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5646 - accuracy: 0.7159 - val_loss: 0.5001 - val_accuracy: 0.7848
# Epoch 82/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5647 - accuracy: 0.7145 - val_loss: 0.4972 - val_accuracy: 0.7910
# Epoch 83/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5657 - accuracy: 0.7165 - val_loss: 0.5034 - val_accuracy: 0.7670
# Epoch 84/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5658 - accuracy: 0.7151 - val_loss: 0.4993 - val_accuracy: 0.7774
# Epoch 85/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5633 - accuracy: 0.7151 - val_loss: 0.5046 - val_accuracy: 0.7734
# Epoch 86/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5647 - accuracy: 0.7144 - val_loss: 0.5017 - val_accuracy: 0.7887
# Epoch 87/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5635 - accuracy: 0.7173 - val_loss: 0.5000 - val_accuracy: 0.7788
# Epoch 88/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5619 - accuracy: 0.7172 - val_loss: 0.5032 - val_accuracy: 0.7827
# Epoch 89/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5656 - accuracy: 0.7136 - val_loss: 0.4982 - val_accuracy: 0.7869
# Epoch 90/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5631 - accuracy: 0.7170 - val_loss: 0.4954 - val_accuracy: 0.7828
# Epoch 91/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5662 - accuracy: 0.7127 - val_loss: 0.5039 - val_accuracy: 0.7761
# Epoch 92/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5663 - accuracy: 0.7132 - val_loss: 0.5070 - val_accuracy: 0.7814
# Epoch 93/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5628 - accuracy: 0.7152 - val_loss: 0.4986 - val_accuracy: 0.7784
# Epoch 94/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5645 - accuracy: 0.7156 - val_loss: 0.4957 - val_accuracy: 0.7697
# Epoch 95/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5660 - accuracy: 0.7135 - val_loss: 0.5009 - val_accuracy: 0.7746
# Epoch 96/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5617 - accuracy: 0.7175 - val_loss: 0.5015 - val_accuracy: 0.7769
# Epoch 97/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5640 - accuracy: 0.7159 - val_loss: 0.5023 - val_accuracy: 0.7810
# Epoch 98/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5649 - accuracy: 0.7132 - val_loss: 0.4989 - val_accuracy: 0.7800
# Epoch 99/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5629 - accuracy: 0.7150 - val_loss: 0.4982 - val_accuracy: 0.7836
# Epoch 100/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5641 - accuracy: 0.7151 - val_loss: 0.4948 - val_accuracy: 0.7822
# Epoch 101/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5633 - accuracy: 0.7155 - val_loss: 0.4983 - val_accuracy: 0.7820
# Epoch 102/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5644 - accuracy: 0.7158 - val_loss: 0.4929 - val_accuracy: 0.7684
# Epoch 103/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5639 - accuracy: 0.7142 - val_loss: 0.5005 - val_accuracy: 0.7847
# Epoch 104/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5644 - accuracy: 0.7164 - val_loss: 0.4984 - val_accuracy: 0.7861
# Epoch 105/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5634 - accuracy: 0.7145 - val_loss: 0.4987 - val_accuracy: 0.7858
# Epoch 106/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5654 - accuracy: 0.7136 - val_loss: 0.4986 - val_accuracy: 0.7854
# Epoch 107/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5668 - accuracy: 0.7125 - val_loss: 0.5038 - val_accuracy: 0.7769
# Epoch 108/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5615 - accuracy: 0.7166 - val_loss: 0.5049 - val_accuracy: 0.7734
# Epoch 109/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5644 - accuracy: 0.7153 - val_loss: 0.5007 - val_accuracy: 0.7812
# Epoch 110/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5622 - accuracy: 0.7155 - val_loss: 0.5044 - val_accuracy: 0.7828
# Epoch 111/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5638 - accuracy: 0.7169 - val_loss: 0.5054 - val_accuracy: 0.7847
# Epoch 112/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5649 - accuracy: 0.7158 - val_loss: 0.4974 - val_accuracy: 0.7808
# Epoch 113/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5652 - accuracy: 0.7154 - val_loss: 0.5011 - val_accuracy: 0.7872
# Epoch 114/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5634 - accuracy: 0.7157 - val_loss: 0.4977 - val_accuracy: 0.7804
# Epoch 115/300
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5641 - accuracy: 0.7158 - val_loss: 0.5031 - val_accuracy: 0.7754
# Epoch 116/300
# 70272/71786 [============================>.] - ETA: 0s - loss: 0.5623 - accuracy: 0.7166

# %%
## get avg precision & avg recall
report= classification_report(Y_test, y_predict, output_dict=True)
avg_list = report.pop("weighted avg")
avg_precision= round(avg_list['precision'], 3)
avg_recall= round(avg_list['recall'], 3)
accuraccy= round(accuracy_score(Y_test,y_predict), 3)
## csv row
csv_row = [get_algo_path(), 'ANN', str(grid_search_acc.best_params_), str(accuraccy), str(avg_precision), str(avg_recall)]
## write file
csv_file= get_csv_path()
write_new_score(csv_file, csv_row)

# %%
## evaluating the model
print("----------")
print('best parameters: ', grid_search_acc.best_params_)
print("----------")
print(confusion_matrix(Y_test,y_predict))
print("----------")
print(classification_report(Y_test, y_predict))
print("----------")
# Out:
# ----------
# best parameters:  {'batch_size': 128, 'optimizer': 'adam'}
# ----------
# [[ 9863  5496]
#  [ 1042 14365]]
# ----------
#               precision    recall  f1-score   support
#
#            0       0.90      0.64      0.75     15359
#            1       0.72      0.93      0.81     15407
#
#     accuracy                           0.79     30766
#    macro avg       0.81      0.79      0.78     30766
# weighted avg       0.81      0.79      0.78     30766
#
# ----------
