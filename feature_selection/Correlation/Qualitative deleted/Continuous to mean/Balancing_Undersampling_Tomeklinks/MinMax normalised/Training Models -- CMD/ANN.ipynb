# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 7s 104us/sample - loss: 0.6599 - accuracy: 0.5819 - val_loss: 0.5807 - val_accuracy: 0.6987
# Epoch 2/200
# 71786/71786 [==============================] - 2s 35us/sample - loss: 0.5624 - accuracy: 0.6817 - val_loss: 0.5001 - val_accuracy: 0.7267
# Epoch 3/200
# 71786/71786 [==============================] - 1s 18us/sample - loss: 0.5180 - accuracy: 0.6998 - val_loss: 0.4733 - val_accuracy: 0.7383
# Epoch 4/200
# 71786/71786 [==============================] - 1s 19us/sample - loss: 0.4966 - accuracy: 0.7117 - val_loss: 0.4595 - val_accuracy: 0.7486
# Epoch 5/200
# 71786/71786 [==============================] - 1s 12us/sample - loss: 0.4818 - accuracy: 0.7231 - val_loss: 0.4513 - val_accuracy: 0.7602
# Epoch 6/200
# 71786/71786 [==============================] - 1s 18us/sample - loss: 0.4726 - accuracy: 0.7296 - val_loss: 0.4442 - val_accuracy: 0.7743
# Epoch 7/200
# ...
