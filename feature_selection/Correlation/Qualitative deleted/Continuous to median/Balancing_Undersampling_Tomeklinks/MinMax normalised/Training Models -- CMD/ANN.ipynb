# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 1s 17us/sample - loss: 0.6863 - accuracy: 0.5418 - val_loss: 0.6630 - val_accuracy: 0.6312
# Epoch 2/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.6484 - accuracy: 0.6212 - val_loss: 0.6017 - val_accuracy: 0.7056
# Epoch 3/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5938 - accuracy: 0.6668 - val_loss: 0.5355 - val_accuracy: 0.7110
# Epoch 4/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5530 - accuracy: 0.6843 - val_loss: 0.4992 - val_accuracy: 0.7292
# Epoch 5/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.5244 - accuracy: 0.6990 - val_loss: 0.4793 - val_accuracy: 0.7382
# Epoch 6/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.5057 - accuracy: 0.7091 - val_loss: 0.4648 - val_accuracy: 0.7476
# Epoch 7/200
# ...
