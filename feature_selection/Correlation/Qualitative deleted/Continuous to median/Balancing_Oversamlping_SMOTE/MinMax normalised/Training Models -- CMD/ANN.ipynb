# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 25us/sample - loss: 0.6701 - accuracy: 0.5848 - val_loss: 0.6332 - val_accuracy: 0.6842
# Epoch 2/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.6160 - accuracy: 0.6564 - val_loss: 0.5601 - val_accuracy: 0.7014
# Epoch 3/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5648 - accuracy: 0.6800 - val_loss: 0.5074 - val_accuracy: 0.7262
# Epoch 4/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5322 - accuracy: 0.6927 - val_loss: 0.4795 - val_accuracy: 0.7572
# Epoch 5/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5074 - accuracy: 0.7077 - val_loss: 0.4606 - val_accuracy: 0.7747
# Epoch 6/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.4905 - accuracy: 0.7193 - val_loss: 0.4493 - val_accuracy: 0.7837
# Epoch 7/200
# ...
