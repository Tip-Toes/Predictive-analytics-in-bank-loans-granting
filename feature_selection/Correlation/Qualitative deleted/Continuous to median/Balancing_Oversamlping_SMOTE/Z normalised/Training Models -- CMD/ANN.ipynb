# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 10s 133us/sample - loss: 0.5803 - accuracy: 0.6446 - val_loss: 0.4976 - val_accuracy: 0.7054
# Epoch 2/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5111 - accuracy: 0.6879 - val_loss: 0.4752 - val_accuracy: 0.7228
# Epoch 3/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4901 - accuracy: 0.7021 - val_loss: 0.4666 - val_accuracy: 0.7329
# Epoch 4/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4788 - accuracy: 0.7167 - val_loss: 0.4558 - val_accuracy: 0.7407
# Epoch 5/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4683 - accuracy: 0.7311 - val_loss: 0.4449 - val_accuracy: 0.7599
# Epoch 6/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4584 - accuracy: 0.7422 - val_loss: 0.4355 - val_accuracy: 0.7721
# Epoch 7/200
# ...
