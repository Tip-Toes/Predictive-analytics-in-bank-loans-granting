# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 1s 18us/sample - loss: 0.6413 - accuracy: 0.5902 - val_loss: 0.5859 - val_accuracy: 0.6653
# Epoch 2/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.5758 - accuracy: 0.6593 - val_loss: 0.5266 - val_accuracy: 0.6912
# Epoch 3/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.5330 - accuracy: 0.6773 - val_loss: 0.4925 - val_accuracy: 0.7111
# Epoch 4/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.5093 - accuracy: 0.6910 - val_loss: 0.4802 - val_accuracy: 0.7224
# Epoch 5/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.4962 - accuracy: 0.6987 - val_loss: 0.4753 - val_accuracy: 0.7315
# Epoch 6/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.4884 - accuracy: 0.7027 - val_loss: 0.4693 - val_accuracy: 0.7332
# Epoch 7/200
# ...
