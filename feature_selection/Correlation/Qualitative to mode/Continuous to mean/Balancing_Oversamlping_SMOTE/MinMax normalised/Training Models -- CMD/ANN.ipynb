# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 4s 58us/sample - loss: 0.6371 - accuracy: 0.6293 - val_loss: 0.5615 - val_accuracy: 0.7293
# Epoch 2/200
# 71786/71786 [==============================] - 8s 110us/sample - loss: 0.5484 - accuracy: 0.7088 - val_loss: 0.4910 - val_accuracy: 0.7777
# Epoch 3/200
# 71786/71786 [==============================] - 4s 58us/sample - loss: 0.5110 - accuracy: 0.7275 - val_loss: 0.4575 - val_accuracy: 0.7794
# Epoch 4/200
# 71786/71786 [==============================] - 3s 36us/sample - loss: 0.4912 - accuracy: 0.7410 - val_loss: 0.4379 - val_accuracy: 0.7991
# Epoch 5/200
# 71786/71786 [==============================] - 2s 23us/sample - loss: 0.4772 - accuracy: 0.7514 - val_loss: 0.4265 - val_accuracy: 0.8057
# Epoch 6/200
# 71786/71786 [==============================] - 2s 25us/sample - loss: 0.4686 - accuracy: 0.7582 - val_loss: 0.4164 - val_accuracy: 0.8127
# Epoch 7/200
# ...
