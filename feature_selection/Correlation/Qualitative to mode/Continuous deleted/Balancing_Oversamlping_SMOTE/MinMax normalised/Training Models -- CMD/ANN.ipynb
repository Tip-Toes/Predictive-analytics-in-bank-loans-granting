# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 1s 17us/sample - loss: 0.6578 - accuracy: 0.5819 - val_loss: 0.6110 - val_accuracy: 0.7027
# Epoch 2/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5982 - accuracy: 0.6620 - val_loss: 0.5440 - val_accuracy: 0.7298
# Epoch 3/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5559 - accuracy: 0.6908 - val_loss: 0.5049 - val_accuracy: 0.7505
# Epoch 4/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5281 - accuracy: 0.7063 - val_loss: 0.4793 - val_accuracy: 0.7596
# Epoch 5/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5093 - accuracy: 0.7160 - val_loss: 0.4628 - val_accuracy: 0.7729
# Epoch 6/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.4950 - accuracy: 0.7246 - val_loss: 0.4510 - val_accuracy: 0.7784
# Epoch 7/200
# ...
