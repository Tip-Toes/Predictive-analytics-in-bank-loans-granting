# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 30us/sample - loss: 0.6099 - accuracy: 0.6226 - val_loss: 0.4932 - val_accuracy: 0.7151
# Epoch 2/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5040 - accuracy: 0.6990 - val_loss: 0.4716 - val_accuracy: 0.7277
# Epoch 3/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4828 - accuracy: 0.7148 - val_loss: 0.4623 - val_accuracy: 0.7366
# Epoch 4/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.4723 - accuracy: 0.7243 - val_loss: 0.4547 - val_accuracy: 0.7461
# Epoch 5/200
# 71786/71786 [==============================] - 1s 17us/sample - loss: 0.4655 - accuracy: 0.7329 - val_loss: 0.4467 - val_accuracy: 0.7569
# Epoch 6/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.4590 - accuracy: 0.7402 - val_loss: 0.4389 - val_accuracy: 0.7682
# Epoch 7/200
# ...
