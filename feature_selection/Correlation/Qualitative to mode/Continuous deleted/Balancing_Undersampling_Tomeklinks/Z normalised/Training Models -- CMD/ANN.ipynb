# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 3s 44us/sample - loss: 0.5764 - accuracy: 0.6429 - val_loss: 0.4813 - val_accuracy: 0.7233
# Epoch 2/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4920 - accuracy: 0.7084 - val_loss: 0.4650 - val_accuracy: 0.7387
# Epoch 3/200
# 71786/71786 [==============================] - 2s 30us/sample - loss: 0.4756 - accuracy: 0.7216 - val_loss: 0.4548 - val_accuracy: 0.7450
# Epoch 4/200
# 71786/71786 [==============================] - 2s 31us/sample - loss: 0.4683 - accuracy: 0.7303 - val_loss: 0.4468 - val_accuracy: 0.7553
# Epoch 5/200
# 71786/71786 [==============================] - 2s 28us/sample - loss: 0.4604 - accuracy: 0.7375 - val_loss: 0.4396 - val_accuracy: 0.7628
# Epoch 6/200
# 71786/71786 [==============================] - 2s 27us/sample - loss: 0.4542 - accuracy: 0.7449 - val_loss: 0.4315 - val_accuracy: 0.7748
# Epoch 7/200
# ...
