# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 32us/sample - loss: 0.6061 - accuracy: 0.6415 - val_loss: 0.4931 - val_accuracy: 0.7549
# Epoch 2/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.5005 - accuracy: 0.7235 - val_loss: 0.4478 - val_accuracy: 0.7795
# Epoch 3/200
# 71786/71786 [==============================] - 2s 27us/sample - loss: 0.4714 - accuracy: 0.7428 - val_loss: 0.4274 - val_accuracy: 0.7989
# Epoch 4/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4580 - accuracy: 0.7562 - val_loss: 0.4138 - val_accuracy: 0.8098
# Epoch 5/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4491 - accuracy: 0.7615 - val_loss: 0.4059 - val_accuracy: 0.8152
# Epoch 6/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4389 - accuracy: 0.7700 - val_loss: 0.3979 - val_accuracy: 0.8157
# Epoch 7/200
# ...
