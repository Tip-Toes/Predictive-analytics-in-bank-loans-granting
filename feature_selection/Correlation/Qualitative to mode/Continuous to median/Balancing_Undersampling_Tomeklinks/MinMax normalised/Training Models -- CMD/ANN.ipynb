# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 32us/sample - loss: 0.5794 - accuracy: 0.6493 - val_loss: 0.4791 - val_accuracy: 0.7299
# Epoch 2/200
# 71786/71786 [==============================] - 2s 23us/sample - loss: 0.4922 - accuracy: 0.7123 - val_loss: 0.4582 - val_accuracy: 0.7370
# Epoch 3/200
# 71786/71786 [==============================] - 2s 27us/sample - loss: 0.4721 - accuracy: 0.7293 - val_loss: 0.4447 - val_accuracy: 0.7619
# Epoch 4/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4603 - accuracy: 0.7401 - val_loss: 0.4309 - val_accuracy: 0.7851
# Epoch 5/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4533 - accuracy: 0.7522 - val_loss: 0.4242 - val_accuracy: 0.7885
# Epoch 6/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4475 - accuracy: 0.7557 - val_loss: 0.4190 - val_accuracy: 0.7974
# Epoch 7/200
# ...
