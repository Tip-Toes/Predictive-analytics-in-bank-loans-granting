# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 4s 50us/sample - loss: 0.6178 - accuracy: 0.6347 - val_loss: 0.5443 - val_accuracy: 0.7006
# Epoch 2/200
# 71786/71786 [==============================] - 1s 9us/sample - loss: 0.5469 - accuracy: 0.6747 - val_loss: 0.4930 - val_accuracy: 0.7173
# Epoch 3/200
# 71786/71786 [==============================] - 0s 7us/sample - loss: 0.5124 - accuracy: 0.6945 - val_loss: 0.4766 - val_accuracy: 0.7271
# Epoch 4/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.4955 - accuracy: 0.7034 - val_loss: 0.4695 - val_accuracy: 0.7328
# Epoch 5/200
# 71786/71786 [==============================] - 1s 7us/sample - loss: 0.4856 - accuracy: 0.7102 - val_loss: 0.4644 - val_accuracy: 0.7371
# Epoch 6/200
# 71786/71786 [==============================] - 0s 7us/sample - loss: 0.4784 - accuracy: 0.7167 - val_loss: 0.4591 - val_accuracy: 0.7398
# Epoch 7/200
# ...
