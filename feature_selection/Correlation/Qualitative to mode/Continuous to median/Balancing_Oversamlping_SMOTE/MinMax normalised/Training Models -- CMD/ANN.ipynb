# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 22us/sample - loss: 0.6404 - accuracy: 0.6015 - val_loss: 0.5192 - val_accuracy: 0.7223
# Epoch 2/200
# 71786/71786 [==============================] - 1s 12us/sample - loss: 0.5225 - accuracy: 0.6972 - val_loss: 0.4742 - val_accuracy: 0.7319
# Epoch 3/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.4882 - accuracy: 0.7201 - val_loss: 0.4515 - val_accuracy: 0.7645
# Epoch 4/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4697 - accuracy: 0.7345 - val_loss: 0.4374 - val_accuracy: 0.7785
# Epoch 5/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4576 - accuracy: 0.7475 - val_loss: 0.4239 - val_accuracy: 0.7959
# Epoch 6/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4486 - accuracy: 0.7573 - val_loss: 0.4155 - val_accuracy: 0.8101
# Epoch 7/200
# ...
