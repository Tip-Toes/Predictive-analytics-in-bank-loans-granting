# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 27us/sample - loss: 0.6294 - accuracy: 0.6000 - val_loss: 0.5299 - val_accuracy: 0.6925
# Epoch 2/200
# 71786/71786 [==============================] - 0s 7us/sample - loss: 0.5396 - accuracy: 0.6808 - val_loss: 0.4927 - val_accuracy: 0.7195
# Epoch 3/200
# 71786/71786 [==============================] - 1s 7us/sample - loss: 0.5135 - accuracy: 0.6976 - val_loss: 0.4801 - val_accuracy: 0.7221
# Epoch 4/200
# 71786/71786 [==============================] - 1s 7us/sample - loss: 0.5015 - accuracy: 0.7055 - val_loss: 0.4728 - val_accuracy: 0.7272
# Epoch 5/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.4925 - accuracy: 0.7119 - val_loss: 0.4664 - val_accuracy: 0.7343
# Epoch 6/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.4871 - accuracy: 0.7171 - val_loss: 0.4614 - val_accuracy: 0.7385
# Epoch 7/200
# ...
