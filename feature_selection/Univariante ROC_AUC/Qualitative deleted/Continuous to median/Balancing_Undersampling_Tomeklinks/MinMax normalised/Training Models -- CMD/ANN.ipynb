# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 9s 127us/sample - loss: 0.6290 - accuracy: 0.6288 - val_loss: 0.5235 - val_accuracy: 0.7099
# Epoch 2/200
# 71786/71786 [==============================] - 2s 22us/sample - loss: 0.5264 - accuracy: 0.6978 - val_loss: 0.4702 - val_accuracy: 0.7372
# Epoch 3/200
# 71786/71786 [==============================] - 2s 21us/sample - loss: 0.4927 - accuracy: 0.7183 - val_loss: 0.4516 - val_accuracy: 0.7624
# Epoch 4/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4732 - accuracy: 0.7326 - val_loss: 0.4410 - val_accuracy: 0.7713
# Epoch 5/200
# 71786/71786 [==============================] - 2s 28us/sample - loss: 0.4646 - accuracy: 0.7402 - val_loss: 0.4360 - val_accuracy: 0.7706
# Epoch 6/200
# 71786/71786 [==============================] - 2s 23us/sample - loss: 0.4575 - accuracy: 0.7454 - val_loss: 0.4286 - val_accuracy: 0.7807
# Epoch 7/200
# ...
