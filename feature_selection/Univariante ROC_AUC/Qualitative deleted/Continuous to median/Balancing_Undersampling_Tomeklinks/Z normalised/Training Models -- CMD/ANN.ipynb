# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 32us/sample - loss: 0.5690 - accuracy: 0.6500 - val_loss: 0.4814 - val_accuracy: 0.7174
# Epoch 2/200
# 71786/71786 [==============================] - 2s 25us/sample - loss: 0.4879 - accuracy: 0.7050 - val_loss: 0.4665 - val_accuracy: 0.7288
# Epoch 3/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4747 - accuracy: 0.7165 - val_loss: 0.4575 - val_accuracy: 0.7366
# Epoch 4/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4667 - accuracy: 0.7251 - val_loss: 0.4505 - val_accuracy: 0.7440
# Epoch 5/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4600 - accuracy: 0.7326 - val_loss: 0.4425 - val_accuracy: 0.7591
# Epoch 6/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4540 - accuracy: 0.7446 - val_loss: 0.4341 - val_accuracy: 0.7771
# Epoch 7/200
# ...
