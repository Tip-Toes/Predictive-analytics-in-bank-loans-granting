# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 7s 102us/sample - loss: 0.6669 - accuracy: 0.5762 - val_loss: 0.6085 - val_accuracy: 0.6950
# Epoch 2/200
# 71786/71786 [==============================] - 1s 18us/sample - loss: 0.5973 - accuracy: 0.6605 - val_loss: 0.5292 - val_accuracy: 0.7230
# Epoch 3/200
# 71786/71786 [==============================] - 1s 16us/sample - loss: 0.5434 - accuracy: 0.6932 - val_loss: 0.4852 - val_accuracy: 0.7438
# Epoch 4/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5103 - accuracy: 0.7118 - val_loss: 0.4601 - val_accuracy: 0.7683
# Epoch 5/200
# 71786/71786 [==============================] - 1s 20us/sample - loss: 0.4869 - accuracy: 0.7265 - val_loss: 0.4449 - val_accuracy: 0.7682
# Epoch 6/200
# 71786/71786 [==============================] - 1s 11us/sample - loss: 0.4693 - accuracy: 0.7382 - val_loss: 0.4341 - val_accuracy: 0.7782
# Epoch 7/200
# ...
