# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 5s 72us/sample - loss: 0.6845 - accuracy: 0.5570 - val_loss: 0.6311 - val_accuracy: 0.7048
# Epoch 2/200
# 71786/71786 [==============================] - 1s 10us/sample - loss: 0.6144 - accuracy: 0.6616 - val_loss: 0.5561 - val_accuracy: 0.7204
# Epoch 3/200
# 71786/71786 [==============================] - 1s 19us/sample - loss: 0.5696 - accuracy: 0.6828 - val_loss: 0.5141 - val_accuracy: 0.7332
# Epoch 4/200
# 71786/71786 [==============================] - 2s 25us/sample - loss: 0.5367 - accuracy: 0.6999 - val_loss: 0.4846 - val_accuracy: 0.7583
# Epoch 5/200
# 71786/71786 [==============================] - 1s 19us/sample - loss: 0.5135 - accuracy: 0.7140 - val_loss: 0.4661 - val_accuracy: 0.7678
# Epoch 6/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4964 - accuracy: 0.7233 - val_loss: 0.4523 - val_accuracy: 0.7854
# Epoch 7/200
# ...
