# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 1s 16us/sample - loss: 0.6528 - accuracy: 0.5874 - val_loss: 0.5643 - val_accuracy: 0.6671
# Epoch 2/200
# 71786/71786 [==============================] - 0s 5us/sample - loss: 0.5699 - accuracy: 0.6502 - val_loss: 0.5122 - val_accuracy: 0.6960
# Epoch 3/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.5331 - accuracy: 0.6748 - val_loss: 0.4898 - val_accuracy: 0.7127
# Epoch 4/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.5114 - accuracy: 0.6909 - val_loss: 0.4789 - val_accuracy: 0.7211
# Epoch 5/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.4997 - accuracy: 0.6986 - val_loss: 0.4731 - val_accuracy: 0.7239
# Epoch 6/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.4928 - accuracy: 0.7061 - val_loss: 0.4696 - val_accuracy: 0.7279
# Epoch 7/200
# ...
