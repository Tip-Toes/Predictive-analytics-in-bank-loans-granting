# %%
import warnings
from pylab import rcParams
from tensorflow_core.python.keras.wrappers.scikit_learn import KerasClassifier
rcParams['figure.figsize'] = 10, 5
from sklearn.model_selection import GridSearchCV
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
import csv
from sklearn.metrics import accuracy_score
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[4:-1]
    cwd='/'.join(cwd)
    return cwd

def get_csv_path():
    import os
    cwd = os.getcwd()
    s="\\"
    if "\\" not in cwd:
        s='/'
    file= cwd.split(s)[:4]
    file.append('models_scores.csv')
    file= s.join(file)
    return file

def line_is_exist(file, row):
    logfile = open(file, 'r')
    loglist = logfile.readlines()
    logfile.close()
    for line in loglist:
        if ','.join(row) in line:
            return True
    return False

def write_new_score(file, line):
    if( not line_is_exist(file, line) ):
        with open(file, 'a') as f:
            writer = csv.writer(f)
            writer.writerow(line)
    else:
        print('line exsist already')

# %%
data= pd.read_csv('../logis_norm.csv')
### split data en X et Y
data1= data.copy()
X= data1.drop('Loan Status', axis=1)
Y= data1['Loan Status']

X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size = 0.30, random_state = 123)

### Neural Network
## ANN Model
def create_model(optimizer):
    model = Sequential()
	#Layer 1
    model.add(Dense(20, activation='relu', input_dim=20))
    model.add(Dropout(0.3))
    #Layer 2
    model.add(Dense(10, activation='relu'))
    model.add(Dropout(0.3))
    
    # output layer
    model.add(Dense(units=1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=50)
ANN = KerasClassifier(build_fn=create_model)

params={'optimizer' : ['adam', 'rmsprop'],
        'batch_size': [128, 256, 512, 800]}


##accuracy
grid_search_acc= GridSearchCV(estimator=ANN, param_grid= params, scoring='accuracy',cv=2, n_jobs=-1)
grid_search_acc= grid_search_acc.fit(X_train, Y_train, epochs=300, validation_data=(X_test, Y_test), callbacks=[early_stop])
y_predict= grid_search_acc.best_estimator_.predict(X_test)
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/300
# 71786/71786 [==============================] - 1s 21us/sample - loss: 0.6893 - accuracy: 0.5384 - val_loss: 0.6712 - val_accuracy: 0.6138
# Epoch 2/300
# 71786/71786 [==============================] - 1s 12us/sample - loss: 0.6729 - accuracy: 0.5866 - val_loss: 0.6552 - val_accuracy: 0.6323
# Epoch 3/300
# 71786/71786 [==============================] - 1s 12us/sample - loss: 0.6617 - accuracy: 0.6115 - val_loss: 0.6426 - val_accuracy: 0.6509
# Epoch 4/300
# 71786/71786 [==============================] - 1s 12us/sample - loss: 0.6539 - accuracy: 0.6238 - val_loss: 0.6291 - val_accuracy: 0.6706
# Epoch 5/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.6440 - accuracy: 0.6402 - val_loss: 0.6129 - val_accuracy: 0.6885
# Epoch 6/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.6357 - accuracy: 0.6497 - val_loss: 0.6019 - val_accuracy: 0.7061
# Epoch 7/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.6282 - accuracy: 0.6573 - val_loss: 0.5877 - val_accuracy: 0.7390
# Epoch 8/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.6228 - accuracy: 0.6619 - val_loss: 0.5796 - val_accuracy: 0.7274
# Epoch 9/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.6149 - accuracy: 0.6697 - val_loss: 0.5708 - val_accuracy: 0.7241
# Epoch 10/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.6126 - accuracy: 0.6746 - val_loss: 0.5632 - val_accuracy: 0.7299
# Epoch 11/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.6057 - accuracy: 0.6799 - val_loss: 0.5553 - val_accuracy: 0.7322
# Epoch 12/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.6049 - accuracy: 0.6816 - val_loss: 0.5565 - val_accuracy: 0.7434
# Epoch 13/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.6024 - accuracy: 0.6813 - val_loss: 0.5505 - val_accuracy: 0.7552
# Epoch 14/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5976 - accuracy: 0.6880 - val_loss: 0.5424 - val_accuracy: 0.7774
# Epoch 15/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5940 - accuracy: 0.6899 - val_loss: 0.5445 - val_accuracy: 0.7547
# Epoch 16/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5945 - accuracy: 0.6903 - val_loss: 0.5504 - val_accuracy: 0.7455
# Epoch 17/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5924 - accuracy: 0.6927 - val_loss: 0.5338 - val_accuracy: 0.7662
# Epoch 18/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5903 - accuracy: 0.6941 - val_loss: 0.5325 - val_accuracy: 0.7623
# Epoch 19/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5902 - accuracy: 0.6939 - val_loss: 0.5366 - val_accuracy: 0.7631
# Epoch 20/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5863 - accuracy: 0.6972 - val_loss: 0.5308 - val_accuracy: 0.7621
# Epoch 21/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5850 - accuracy: 0.6993 - val_loss: 0.5343 - val_accuracy: 0.7533
# Epoch 22/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5841 - accuracy: 0.6982 - val_loss: 0.5243 - val_accuracy: 0.7666
# Epoch 23/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5812 - accuracy: 0.6992 - val_loss: 0.5255 - val_accuracy: 0.7693
# Epoch 24/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5847 - accuracy: 0.6981 - val_loss: 0.5203 - val_accuracy: 0.7690
# Epoch 25/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5797 - accuracy: 0.6994 - val_loss: 0.5272 - val_accuracy: 0.7570
# Epoch 26/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5790 - accuracy: 0.7040 - val_loss: 0.5306 - val_accuracy: 0.7549
# Epoch 27/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5797 - accuracy: 0.7009 - val_loss: 0.5210 - val_accuracy: 0.7664
# Epoch 28/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5772 - accuracy: 0.7018 - val_loss: 0.5194 - val_accuracy: 0.7649
# Epoch 29/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5798 - accuracy: 0.6994 - val_loss: 0.5157 - val_accuracy: 0.7709
# Epoch 30/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5781 - accuracy: 0.7005 - val_loss: 0.5206 - val_accuracy: 0.7619
# Epoch 31/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5801 - accuracy: 0.7011 - val_loss: 0.5206 - val_accuracy: 0.7614
# Epoch 32/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5783 - accuracy: 0.7015 - val_loss: 0.5280 - val_accuracy: 0.7510
# Epoch 33/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5767 - accuracy: 0.7041 - val_loss: 0.5159 - val_accuracy: 0.7591
# Epoch 34/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5756 - accuracy: 0.7019 - val_loss: 0.5175 - val_accuracy: 0.7671
# Epoch 35/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5766 - accuracy: 0.7026 - val_loss: 0.5209 - val_accuracy: 0.7548
# Epoch 36/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5767 - accuracy: 0.7035 - val_loss: 0.5165 - val_accuracy: 0.7630
# Epoch 37/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5745 - accuracy: 0.7043 - val_loss: 0.5170 - val_accuracy: 0.7637
# Epoch 38/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5749 - accuracy: 0.7030 - val_loss: 0.5095 - val_accuracy: 0.7717
# Epoch 39/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5731 - accuracy: 0.7055 - val_loss: 0.5160 - val_accuracy: 0.7593
# Epoch 40/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5749 - accuracy: 0.7025 - val_loss: 0.5096 - val_accuracy: 0.7698
# Epoch 41/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5766 - accuracy: 0.7039 - val_loss: 0.5183 - val_accuracy: 0.7583
# Epoch 42/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5730 - accuracy: 0.7050 - val_loss: 0.5194 - val_accuracy: 0.7547
# Epoch 43/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5718 - accuracy: 0.7066 - val_loss: 0.5110 - val_accuracy: 0.7649
# Epoch 44/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5746 - accuracy: 0.7042 - val_loss: 0.5139 - val_accuracy: 0.7656
# Epoch 45/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5732 - accuracy: 0.7047 - val_loss: 0.5163 - val_accuracy: 0.7648
# Epoch 46/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5717 - accuracy: 0.7064 - val_loss: 0.5231 - val_accuracy: 0.7451
# Epoch 47/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5736 - accuracy: 0.7052 - val_loss: 0.5126 - val_accuracy: 0.7671
# Epoch 48/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5723 - accuracy: 0.7065 - val_loss: 0.5204 - val_accuracy: 0.7522
# Epoch 49/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5707 - accuracy: 0.7069 - val_loss: 0.5165 - val_accuracy: 0.7542
# Epoch 50/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5711 - accuracy: 0.7068 - val_loss: 0.5099 - val_accuracy: 0.7630
# Epoch 51/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5723 - accuracy: 0.7057 - val_loss: 0.5121 - val_accuracy: 0.7666
# Epoch 52/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5717 - accuracy: 0.7053 - val_loss: 0.5080 - val_accuracy: 0.7667
# Epoch 53/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5702 - accuracy: 0.7051 - val_loss: 0.5087 - val_accuracy: 0.7684
# Epoch 54/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5711 - accuracy: 0.7055 - val_loss: 0.5093 - val_accuracy: 0.7764
# Epoch 55/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5694 - accuracy: 0.7074 - val_loss: 0.5045 - val_accuracy: 0.7756
# Epoch 56/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5706 - accuracy: 0.7066 - val_loss: 0.5133 - val_accuracy: 0.7554
# Epoch 57/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5723 - accuracy: 0.7044 - val_loss: 0.5178 - val_accuracy: 0.7630
# Epoch 58/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5704 - accuracy: 0.7063 - val_loss: 0.5125 - val_accuracy: 0.7597
# Epoch 59/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5705 - accuracy: 0.7053 - val_loss: 0.5177 - val_accuracy: 0.7635
# Epoch 60/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5689 - accuracy: 0.7075 - val_loss: 0.5100 - val_accuracy: 0.7615
# Epoch 61/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5735 - accuracy: 0.7045 - val_loss: 0.5068 - val_accuracy: 0.7661
# Epoch 62/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5685 - accuracy: 0.7077 - val_loss: 0.5049 - val_accuracy: 0.7668
# Epoch 63/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5700 - accuracy: 0.7075 - val_loss: 0.5071 - val_accuracy: 0.7676
# Epoch 64/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5695 - accuracy: 0.7048 - val_loss: 0.5094 - val_accuracy: 0.7658
# Epoch 65/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5703 - accuracy: 0.7074 - val_loss: 0.5077 - val_accuracy: 0.7667
# Epoch 66/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5697 - accuracy: 0.7071 - val_loss: 0.5162 - val_accuracy: 0.7603
# Epoch 67/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5706 - accuracy: 0.7054 - val_loss: 0.5099 - val_accuracy: 0.7671
# Epoch 68/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5706 - accuracy: 0.7057 - val_loss: 0.5131 - val_accuracy: 0.7584
# Epoch 69/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5704 - accuracy: 0.7039 - val_loss: 0.5114 - val_accuracy: 0.7665
# Epoch 70/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5678 - accuracy: 0.7085 - val_loss: 0.5050 - val_accuracy: 0.7694
# Epoch 71/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5702 - accuracy: 0.7062 - val_loss: 0.5133 - val_accuracy: 0.7588
# Epoch 72/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5705 - accuracy: 0.7056 - val_loss: 0.5103 - val_accuracy: 0.7655
# Epoch 73/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5692 - accuracy: 0.7058 - val_loss: 0.5097 - val_accuracy: 0.7617
# Epoch 74/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5688 - accuracy: 0.7063 - val_loss: 0.5182 - val_accuracy: 0.7507
# Epoch 75/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5715 - accuracy: 0.7064 - val_loss: 0.5087 - val_accuracy: 0.7618
# Epoch 76/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5713 - accuracy: 0.7032 - val_loss: 0.5105 - val_accuracy: 0.7624
# Epoch 77/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5678 - accuracy: 0.7065 - val_loss: 0.5083 - val_accuracy: 0.7657
# Epoch 78/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5677 - accuracy: 0.7092 - val_loss: 0.5048 - val_accuracy: 0.7700
# Epoch 79/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5679 - accuracy: 0.7072 - val_loss: 0.5047 - val_accuracy: 0.7719
# Epoch 80/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5680 - accuracy: 0.7059 - val_loss: 0.5182 - val_accuracy: 0.7546
# Epoch 81/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5692 - accuracy: 0.7074 - val_loss: 0.5118 - val_accuracy: 0.7652
# Epoch 82/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5698 - accuracy: 0.7077 - val_loss: 0.5225 - val_accuracy: 0.7513
# Epoch 83/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5709 - accuracy: 0.7054 - val_loss: 0.5093 - val_accuracy: 0.7717
# Epoch 84/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5675 - accuracy: 0.7074 - val_loss: 0.5043 - val_accuracy: 0.7694
# Epoch 85/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5672 - accuracy: 0.7083 - val_loss: 0.4996 - val_accuracy: 0.7613
# Epoch 86/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5689 - accuracy: 0.7084 - val_loss: 0.5092 - val_accuracy: 0.7656
# Epoch 87/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5679 - accuracy: 0.7089 - val_loss: 0.5110 - val_accuracy: 0.7679
# Epoch 88/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5693 - accuracy: 0.7057 - val_loss: 0.5092 - val_accuracy: 0.7681
# Epoch 89/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5687 - accuracy: 0.7052 - val_loss: 0.5030 - val_accuracy: 0.7759
# Epoch 90/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5672 - accuracy: 0.7071 - val_loss: 0.5146 - val_accuracy: 0.7636
# Epoch 91/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5672 - accuracy: 0.7072 - val_loss: 0.5036 - val_accuracy: 0.7739
# Epoch 92/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5683 - accuracy: 0.7055 - val_loss: 0.5025 - val_accuracy: 0.7726
# Epoch 93/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5684 - accuracy: 0.7062 - val_loss: 0.5062 - val_accuracy: 0.7676
# Epoch 94/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5670 - accuracy: 0.7074 - val_loss: 0.5052 - val_accuracy: 0.7713
# Epoch 95/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5662 - accuracy: 0.7099 - val_loss: 0.5060 - val_accuracy: 0.7734
# Epoch 96/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5702 - accuracy: 0.7050 - val_loss: 0.5098 - val_accuracy: 0.7592
# Epoch 97/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5683 - accuracy: 0.7073 - val_loss: 0.5088 - val_accuracy: 0.7678
# Epoch 98/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5654 - accuracy: 0.7100 - val_loss: 0.5010 - val_accuracy: 0.7750
# Epoch 99/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5673 - accuracy: 0.7095 - val_loss: 0.5025 - val_accuracy: 0.7761
# Epoch 100/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5662 - accuracy: 0.7100 - val_loss: 0.5091 - val_accuracy: 0.7620
# Epoch 101/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5704 - accuracy: 0.7058 - val_loss: 0.5098 - val_accuracy: 0.7593
# Epoch 102/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5689 - accuracy: 0.7069 - val_loss: 0.5111 - val_accuracy: 0.7670
# Epoch 103/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5690 - accuracy: 0.7073 - val_loss: 0.5049 - val_accuracy: 0.7710
# Epoch 104/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5694 - accuracy: 0.7064 - val_loss: 0.5131 - val_accuracy: 0.7644
# Epoch 105/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5690 - accuracy: 0.7064 - val_loss: 0.5101 - val_accuracy: 0.7667
# Epoch 106/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5681 - accuracy: 0.7075 - val_loss: 0.5096 - val_accuracy: 0.7730
# Epoch 107/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5657 - accuracy: 0.7094 - val_loss: 0.5060 - val_accuracy: 0.7700
# Epoch 108/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5662 - accuracy: 0.7077 - val_loss: 0.5057 - val_accuracy: 0.7644
# Epoch 109/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5677 - accuracy: 0.7067 - val_loss: 0.5105 - val_accuracy: 0.7638
# Epoch 110/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5661 - accuracy: 0.7081 - val_loss: 0.5023 - val_accuracy: 0.7733
# Epoch 111/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5687 - accuracy: 0.7065 - val_loss: 0.5076 - val_accuracy: 0.7690
# Epoch 112/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5664 - accuracy: 0.7064 - val_loss: 0.5074 - val_accuracy: 0.7700
# Epoch 113/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5658 - accuracy: 0.7101 - val_loss: 0.5035 - val_accuracy: 0.7797
# Epoch 114/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5690 - accuracy: 0.7060 - val_loss: 0.5085 - val_accuracy: 0.7734
# Epoch 115/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5688 - accuracy: 0.7076 - val_loss: 0.5073 - val_accuracy: 0.7732
# Epoch 116/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5672 - accuracy: 0.7077 - val_loss: 0.5052 - val_accuracy: 0.7715
# Epoch 117/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5668 - accuracy: 0.7090 - val_loss: 0.5003 - val_accuracy: 0.7736
# Epoch 118/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5671 - accuracy: 0.7066 - val_loss: 0.5053 - val_accuracy: 0.7754
# Epoch 119/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5666 - accuracy: 0.7068 - val_loss: 0.5094 - val_accuracy: 0.7611
# Epoch 120/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5674 - accuracy: 0.7060 - val_loss: 0.5136 - val_accuracy: 0.7537
# Epoch 121/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5654 - accuracy: 0.7090 - val_loss: 0.5068 - val_accuracy: 0.7709
# Epoch 122/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5699 - accuracy: 0.7064 - val_loss: 0.5058 - val_accuracy: 0.7673
# Epoch 123/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5662 - accuracy: 0.7088 - val_loss: 0.5061 - val_accuracy: 0.7704
# Epoch 124/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5684 - accuracy: 0.7078 - val_loss: 0.5109 - val_accuracy: 0.7624
# Epoch 125/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5663 - accuracy: 0.7095 - val_loss: 0.5044 - val_accuracy: 0.7654
# Epoch 126/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5682 - accuracy: 0.7082 - val_loss: 0.5086 - val_accuracy: 0.7632
# Epoch 127/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5651 - accuracy: 0.7090 - val_loss: 0.5062 - val_accuracy: 0.7726
# Epoch 128/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5653 - accuracy: 0.7074 - val_loss: 0.5050 - val_accuracy: 0.7731
# Epoch 129/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5646 - accuracy: 0.7086 - val_loss: 0.5038 - val_accuracy: 0.7721
# Epoch 130/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5673 - accuracy: 0.7082 - val_loss: 0.5045 - val_accuracy: 0.7697
# Epoch 131/300
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5674 - accuracy: 0.7078 - val_loss: 0.5054 - val_accuracy: 0.7728
# Epoch 132/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5679 - accuracy: 0.7076 - val_loss: 0.5129 - val_accuracy: 0.7617
# Epoch 133/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5661 - accuracy: 0.7069 - val_loss: 0.5092 - val_accuracy: 0.7664
# Epoch 134/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5652 - accuracy: 0.7101 - val_loss: 0.5008 - val_accuracy: 0.7813
# Epoch 135/300
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.5674 - accuracy: 0.7079 - val_loss: 0.5050 - val_accuracy: 0.7633

# %%
## get avg precision & avg recall
report= classification_report(Y_test, y_predict, output_dict=True)
avg_list = report.pop("weighted avg")
avg_precision= round(avg_list['precision'], 3)
avg_recall= round(avg_list['recall'], 3)
accuraccy= round(accuracy_score(Y_test,y_predict), 3)
## csv row
csv_row = [get_algo_path(), 'ANN', str(grid_search_acc.best_params_), str(accuraccy), str(avg_precision), str(avg_recall)]
## write file
csv_file= get_csv_path()
write_new_score(csv_file, csv_row)

# %%
## evaluating the model
print("----------")
print('best parameters: ', grid_search_acc.best_params_)
print("----------")
print(confusion_matrix(Y_test,y_predict))
print("----------")
print(classification_report(Y_test, y_predict))
print("----------")
# Out:
# ----------
# best parameters:  {'batch_size': 256, 'optimizer': 'adam'}
# ----------
# [[ 8579  6780]
#  [  503 14904]]
# ----------
#               precision    recall  f1-score   support
#
#            0       0.94      0.56      0.70     15359
#            1       0.69      0.97      0.80     15407
#
#     accuracy                           0.76     30766
#    macro avg       0.82      0.76      0.75     30766
# weighted avg       0.82      0.76      0.75     30766
#
# ----------
