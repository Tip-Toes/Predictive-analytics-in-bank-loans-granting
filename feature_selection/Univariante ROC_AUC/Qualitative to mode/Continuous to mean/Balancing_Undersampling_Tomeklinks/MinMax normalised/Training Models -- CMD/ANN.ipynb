# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 9s 128us/sample - loss: 0.6168 - accuracy: 0.6323 - val_loss: 0.5101 - val_accuracy: 0.7261
# Epoch 2/200
# 71786/71786 [==============================] - 2s 25us/sample - loss: 0.5159 - accuracy: 0.7038 - val_loss: 0.4617 - val_accuracy: 0.7549
# Epoch 3/200
# 71786/71786 [==============================] - 1s 18us/sample - loss: 0.4822 - accuracy: 0.7267 - val_loss: 0.4390 - val_accuracy: 0.7823
# Epoch 4/200
# 71786/71786 [==============================] - 2s 23us/sample - loss: 0.4665 - accuracy: 0.7406 - val_loss: 0.4333 - val_accuracy: 0.7811
# Epoch 5/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4565 - accuracy: 0.7480 - val_loss: 0.4260 - val_accuracy: 0.7860
# Epoch 6/200
# 71786/71786 [==============================] - 2s 24us/sample - loss: 0.4494 - accuracy: 0.7516 - val_loss: 0.4182 - val_accuracy: 0.8039
# Epoch 7/200
# ...
