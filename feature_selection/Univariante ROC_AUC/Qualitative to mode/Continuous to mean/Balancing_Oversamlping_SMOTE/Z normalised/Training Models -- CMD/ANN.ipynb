# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 23us/sample - loss: 0.6035 - accuracy: 0.6364 - val_loss: 0.5040 - val_accuracy: 0.7117
# Epoch 2/200
# 71786/71786 [==============================] - 1s 12us/sample - loss: 0.5179 - accuracy: 0.6977 - val_loss: 0.4734 - val_accuracy: 0.7289
# Epoch 3/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.4938 - accuracy: 0.7103 - val_loss: 0.4633 - val_accuracy: 0.7372
# Epoch 4/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.4858 - accuracy: 0.7162 - val_loss: 0.4579 - val_accuracy: 0.7424
# Epoch 5/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.4774 - accuracy: 0.7243 - val_loss: 0.4521 - val_accuracy: 0.7485
# Epoch 6/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.4720 - accuracy: 0.7265 - val_loss: 0.4484 - val_accuracy: 0.7511
# Epoch 7/200
# ...
