# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 33us/sample - loss: 0.5455 - accuracy: 0.6765 - val_loss: 0.4741 - val_accuracy: 0.7265
# Epoch 2/200
# 71786/71786 [==============================] - 2s 25us/sample - loss: 0.4850 - accuracy: 0.7118 - val_loss: 0.4613 - val_accuracy: 0.7413
# Epoch 3/200
# 71786/71786 [==============================] - 2s 25us/sample - loss: 0.4729 - accuracy: 0.7252 - val_loss: 0.4515 - val_accuracy: 0.7479
# Epoch 4/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4633 - accuracy: 0.7344 - val_loss: 0.4423 - val_accuracy: 0.7626
# Epoch 5/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4565 - accuracy: 0.7445 - val_loss: 0.4351 - val_accuracy: 0.7796
# Epoch 6/200
# 71786/71786 [==============================] - 2s 26us/sample - loss: 0.4488 - accuracy: 0.7515 - val_loss: 0.4257 - val_accuracy: 0.7869
# Epoch 7/200
# ...
