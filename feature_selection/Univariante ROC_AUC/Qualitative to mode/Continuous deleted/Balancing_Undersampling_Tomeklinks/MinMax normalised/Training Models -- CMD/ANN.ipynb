# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 4s 57us/sample - loss: 0.5786 - accuracy: 0.6601 - val_loss: 0.4786 - val_accuracy: 0.7388
# Epoch 2/200
# 71786/71786 [==============================] - 2s 29us/sample - loss: 0.4958 - accuracy: 0.7139 - val_loss: 0.4514 - val_accuracy: 0.7541
# Epoch 3/200
# 71786/71786 [==============================] - 2s 28us/sample - loss: 0.4726 - accuracy: 0.7334 - val_loss: 0.4359 - val_accuracy: 0.7878
# Epoch 4/200
# 71786/71786 [==============================] - 2s 28us/sample - loss: 0.4611 - accuracy: 0.7448 - val_loss: 0.4301 - val_accuracy: 0.7762
# Epoch 5/200
# 71786/71786 [==============================] - 2s 28us/sample - loss: 0.4520 - accuracy: 0.7540 - val_loss: 0.4188 - val_accuracy: 0.8013
# Epoch 6/200
# 71786/71786 [==============================] - 2s 28us/sample - loss: 0.4467 - accuracy: 0.7596 - val_loss: 0.4105 - val_accuracy: 0.8103
# Epoch 7/200
# ...
