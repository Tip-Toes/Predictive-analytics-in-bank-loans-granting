# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 2s 23us/sample - loss: 0.5978 - accuracy: 0.6403 - val_loss: 0.4990 - val_accuracy: 0.7194
# Epoch 2/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.5122 - accuracy: 0.6995 - val_loss: 0.4739 - val_accuracy: 0.7314
# Epoch 3/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4915 - accuracy: 0.7102 - val_loss: 0.4659 - val_accuracy: 0.7413
# Epoch 4/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4807 - accuracy: 0.7177 - val_loss: 0.4582 - val_accuracy: 0.7463
# Epoch 5/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4734 - accuracy: 0.7245 - val_loss: 0.4513 - val_accuracy: 0.7557
# Epoch 6/200
# 71786/71786 [==============================] - 1s 15us/sample - loss: 0.4662 - accuracy: 0.7364 - val_loss: 0.4440 - val_accuracy: 0.7644
# Epoch 7/200
# ...
