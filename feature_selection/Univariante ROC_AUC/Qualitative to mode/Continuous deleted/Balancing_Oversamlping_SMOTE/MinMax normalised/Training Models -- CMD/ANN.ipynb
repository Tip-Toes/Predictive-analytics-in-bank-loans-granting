# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 6s 88us/sample - loss: 0.6846 - accuracy: 0.5380 - val_loss: 0.6481 - val_accuracy: 0.6897
# Epoch 2/200
# 71786/71786 [==============================] - 1s 14us/sample - loss: 0.6326 - accuracy: 0.6357 - val_loss: 0.5817 - val_accuracy: 0.7155
# Epoch 3/200
# 71786/71786 [==============================] - 1s 11us/sample - loss: 0.5774 - accuracy: 0.6695 - val_loss: 0.5200 - val_accuracy: 0.7272
# Epoch 4/200
# 71786/71786 [==============================] - 1s 9us/sample - loss: 0.5379 - accuracy: 0.6971 - val_loss: 0.4903 - val_accuracy: 0.7410
# Epoch 5/200
# 71786/71786 [==============================] - 0s 6us/sample - loss: 0.5192 - accuracy: 0.7099 - val_loss: 0.4728 - val_accuracy: 0.7479
# Epoch 6/200
# 71786/71786 [==============================] - 0s 7us/sample - loss: 0.5039 - accuracy: 0.7196 - val_loss: 0.4594 - val_accuracy: 0.7702
# Epoch 7/200
# ...
