# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 3s 35us/sample - loss: 0.6289 - accuracy: 0.6047 - val_loss: 0.5288 - val_accuracy: 0.7051
# Epoch 2/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.5356 - accuracy: 0.6818 - val_loss: 0.4845 - val_accuracy: 0.7259
# Epoch 3/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.5070 - accuracy: 0.7011 - val_loss: 0.4731 - val_accuracy: 0.7317
# Epoch 4/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.4925 - accuracy: 0.7101 - val_loss: 0.4661 - val_accuracy: 0.7385
# Epoch 5/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.4844 - accuracy: 0.7154 - val_loss: 0.4601 - val_accuracy: 0.7390
# Epoch 6/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.4778 - accuracy: 0.7218 - val_loss: 0.4561 - val_accuracy: 0.7467
# Epoch 7/200
# ...
