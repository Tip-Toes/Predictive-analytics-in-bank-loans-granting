# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 7s 92us/sample - loss: 0.6286 - accuracy: 0.6159 - val_loss: 0.5186 - val_accuracy: 0.7109
# Epoch 2/200
# 71786/71786 [==============================] - 2s 33us/sample - loss: 0.5271 - accuracy: 0.6917 - val_loss: 0.4753 - val_accuracy: 0.7359
# Epoch 3/200
# 71786/71786 [==============================] - 5s 64us/sample - loss: 0.4964 - accuracy: 0.7094 - val_loss: 0.4581 - val_accuracy: 0.7558
# Epoch 4/200
# 71786/71786 [==============================] - 3s 36us/sample - loss: 0.4780 - accuracy: 0.7226 - val_loss: 0.4474 - val_accuracy: 0.7608
# Epoch 5/200
# 71786/71786 [==============================] - 2s 22us/sample - loss: 0.4647 - accuracy: 0.7358 - val_loss: 0.4353 - val_accuracy: 0.7719
# Epoch 6/200
# 71786/71786 [==============================] - 1s 18us/sample - loss: 0.4573 - accuracy: 0.7435 - val_loss: 0.4284 - val_accuracy: 0.7839
# Epoch 7/200
# ...
