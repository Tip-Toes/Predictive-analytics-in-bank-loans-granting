# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/MinMax normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/MinMax normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 8s 106us/sample - loss: 0.6554 - accuracy: 0.5958 - val_loss: 0.5801 - val_accuracy: 0.7171
# Epoch 2/200
# 71786/71786 [==============================] - 1s 19us/sample - loss: 0.5746 - accuracy: 0.6773 - val_loss: 0.5053 - val_accuracy: 0.7379
# Epoch 3/200
# 71786/71786 [==============================] - 1s 10us/sample - loss: 0.5247 - accuracy: 0.7100 - val_loss: 0.4684 - val_accuracy: 0.7495
# Epoch 4/200
# 71786/71786 [==============================] - 1s 11us/sample - loss: 0.4967 - accuracy: 0.7238 - val_loss: 0.4474 - val_accuracy: 0.7903
# Epoch 5/200
# 71786/71786 [==============================] - 1s 10us/sample - loss: 0.4788 - accuracy: 0.7365 - val_loss: 0.4361 - val_accuracy: 0.7981
# Epoch 6/200
# 71786/71786 [==============================] - 1s 10us/sample - loss: 0.4656 - accuracy: 0.7468 - val_loss: 0.4278 - val_accuracy: 0.7990
# Epoch 7/200
# ...
