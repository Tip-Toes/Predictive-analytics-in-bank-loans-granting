# %%
def get_algo_path():
    import os
    cwd = os.getcwd()
    s='\\'
    if '\\' not in cwd:
        s='/'
    cwd= cwd.split(s)[:4]
    #cwd.append('loaded')
    cwd='/'.join(cwd)
    return cwd
path=get_algo_path()+'/loaded/Z normalised/ANN.py'
path
# Out:
# 'C:/Users/Omar/00_Bank_loan_project/loaded/Z normalised/ANN.py'

# %%
exec(open(path).read())
# Out:
# Train on 71786 samples, validate on 30766 samples
# Epoch 1/200
# 71786/71786 [==============================] - 1s 18us/sample - loss: 0.6398 - accuracy: 0.5860 - val_loss: 0.5575 - val_accuracy: 0.6911
# Epoch 2/200
# 71786/71786 [==============================] - 1s 7us/sample - loss: 0.5468 - accuracy: 0.6771 - val_loss: 0.4953 - val_accuracy: 0.7155
# Epoch 3/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.5129 - accuracy: 0.6975 - val_loss: 0.4762 - val_accuracy: 0.7250
# Epoch 4/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.4983 - accuracy: 0.7068 - val_loss: 0.4682 - val_accuracy: 0.7317
# Epoch 5/200
# 71786/71786 [==============================] - 1s 8us/sample - loss: 0.4912 - accuracy: 0.7132 - val_loss: 0.4616 - val_accuracy: 0.7429
# Epoch 6/200
# 71786/71786 [==============================] - 1s 9us/sample - loss: 0.4844 - accuracy: 0.7192 - val_loss: 0.4572 - val_accuracy: 0.7454
# Epoch 7/200
# ...
